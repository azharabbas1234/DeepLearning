# %%
from PIL import Image
import numpy as np
import matplotlib as plt
image=Image.open('my_image.jpg')
gray_image = image.convert('L')
gray_image.save('gray_image.jpg')
image.show()

# %%
cropped=image.crop((100,100,200,200))
cropped.show()

# %%
rotate=image.rotate(180, expand=True)
rotate.show()

# %%
flip=image.transpose(Image.FLIP_LEFT_RIGHT)
flip.show()
# Out:
# <bound method Image.show of <PIL.Image.Image image mode=RGB size=2992x2000 at 0x1D3055D7E30>>

# %%
# # Split into RGB channels
# R = img_array[:, :, 0]  # Red channel
# G = img_array[:, :, 1]  # Green channel
# B = img_array[:, :, 2]  # Blue channel

# print("R shape:", R.shape)
# print("G shape:", G.shape)
# print("B shape:", B.shape)
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 3))

# plt.subplot(1, 3, 1)
# plt.imshow(R, cmap='Reds')
# plt.title("Red Channel")

# plt.subplot(1, 3, 2)
# plt.imshow(G, cmap='Greens')
# plt.title("Green Channel")

# plt.subplot(1, 3, 3)
# plt.imshow(B, cmap='Blues')
# plt.title("Blue Channel")

# plt.show()
# Out:
# Original size: (2992, 2000)
# Reduced size: (100, 100)
# R shape: (100, 100)
# G shape: (100, 100)
# B shape: (100, 100)
